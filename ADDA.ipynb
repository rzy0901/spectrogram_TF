# %% [markdown]
# Unsupervised Adversarial Discriminative Domain Adpatation (ADDA) on spectrograms

# %%
import torch
import glob
import os
import cv2
from tqdm import tqdm
import numpy as np
from torchvision.transforms import transforms
from data import MyDataset
from torch.utils.data import DataLoader
# from torch.utils.tensorboard import SummaryWriter
from torch import nn

# %%
batch_size = 16
iterations = 10
epochs = 100
k_disc = 10
k_clf = 1

MODEL_FILE = './model1/resnet18_model.pth' # pretrained model using simulated dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from models import fc_part, FeatureExtractorResNet18, ClassifierResNet, Discriminator
from utils import set_requires_grad
from torchvision.models import resnet18

source_model = resnet18(pretrained=True).to(device)
source_model.fc = fc_part().to(device)
source_model.load_state_dict(torch.load(MODEL_FILE))
source_model.eval()
set_requires_grad(source_model)

clf = source_model
source_feature_extractor = FeatureExtractorResNet18(source_model) # source feature extractor
source_classifier = ClassifierResNet(source_model) 

target_model = resnet18(pretrained=True).to(device)
target_model.fc = fc_part().to(device)
target_model.load_state_dict(torch.load(MODEL_FILE))
target_feature_extractor = FeatureExtractorResNet18(target_model) # target feature extractor
target_classifier = ClassifierResNet(target_model) 

discriminator = Discriminator().to(device)

# %%
half_batch = batch_size // 2

source_path = './train/' # 3*60 simulated imgs copied from <https://github.com/Jcq242818/CASTER/tree/retraining2/model1/train>
target_train_path = './train_target_3x30/' # 3*10 real imgs without labels copied from <https://github.com/Jcq242818/CASTER/tree/retraining2/model2/train>
target_test_path = './test/' # 3*40 real test imgs copied from <https://github.com/Jcq242818/CASTER/tree/retraining2/model1/test>
source_txt_path = './train/train.txt'
target_train_txt_path = './train_target_3x30/train.txt'
target_test_txt_path = './test/test.txt'
output_path = './output_DA'
log_path = './output_DA/log'

source_all = {}
target_train_all = {}
target_test_all = {}
for trainable in [True,False]:
    if trainable:
        for category in ['pic1','pic2','pic3']:
            source_all[category] = glob.glob(os.path.join(source_path + category,'*.jpg'))
            target_train_all[category] = glob.glob(os.path.join(target_train_path + category,'*.jpg'))
    else:
        for category in ['pic1','pic2','pic3']:
            target_test_all[category] = glob.glob(os.path.join(target_test_path + category,'*.jpg'))

mapkey = {
    'pic1' : '0',
    'pic2' : '1',
    'pic3' : '2',
}

def gen_txt(txt_path, img_paths):
    f = open(txt_path,'w')
    for key in img_paths.keys():
        label = mapkey[key]
        for path in img_paths[key]:
            line = path + ' ' + label +'\n'
            f.write(line)

gen_txt(source_txt_path,source_all)
gen_txt(target_train_txt_path,target_train_all)
gen_txt(target_test_txt_path,target_test_all)

if not os.path.exists(output_path):
    os.makedirs(output_path)

if os.path.exists(log_path):
    import shutil
    shutil.rmtree(log_path)
# tb = SummaryWriter(log_dir=log_path)

source_paths = source_all['pic1'] + source_all['pic2'] + source_all['pic3']
m_list, s_list = [], []

for path in tqdm(source_paths):
    img = cv2.imread(path)
    img = img / 255.0
    m, s = cv2.meanStdDev(img)
    m_list.append(m.reshape((3,)))
    s_list.append(s.reshape((3,)))

m_array = np.array(m_list)
s_array = np.array(s_list)
m = m_array.mean(axis=0, keepdims=True)
s = s_array.mean(axis=0, keepdims=True)
normMean = m[0][::-1].copy()
normStd = s[0][::-1].copy()
normTransform = transforms.Normalize(normMean, normStd)
sourceTransform = transforms.Compose([
    transforms.ToTensor(),
    normTransform,
])
targetTransform = transforms.Compose([
    transforms.ToTensor(),
    normTransform,
])

source_data = MyDataset(txt_path=source_txt_path, transform=sourceTransform)
target_train_data = MyDataset(txt_path=target_train_txt_path, transform=targetTransform)
target_test_data = MyDataset(txt_path=target_test_txt_path, transform=targetTransform)

source_loader = DataLoader(dataset=source_data, batch_size=half_batch, shuffle=True)
target_train_loader = DataLoader(dataset=target_train_data, batch_size=half_batch,shuffle=True)
target_test_loader = DataLoader(dataset=target_test_data, batch_size=batch_size)

discriminator_optim = torch.optim.Adam(discriminator.parameters(),lr=0.0001,betas=(0.5,0.999))
# discriminator_optim = torch.optim.SGD(discriminator.parameters(), lr= 0.0001, momentum=0.9)

target_optim = torch.optim.Adam(target_feature_extractor.parameters(),lr=0.0001,betas=(0.5,0.999))
# target_optim = torch.optim.SGD(target_feature_extractor.parameters(), lr= 0.0001, momentum=0.9)

criterion_train = nn.BCEWithLogitsLoss()
criterion_test = nn.CrossEntropyLoss()
# Out:
# 100%|██████████| 180/180 [00:00<00:00, 6951.44it/s]

# %%
from utils import visualize_batches_from_dataloader

visualize_batches_from_dataloader(source_loader,nbatches=2, cmap='gray', title='Source images')
visualize_batches_from_dataloader(target_train_loader,nbatches=2, cmap='gray', title='Target images')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
disc_losses, disc_accuracies, disc_train_counter = [], [], []
clf_disc_losses, clf_disc_train_counter = [], []
clf_losses, clf_accuracies = [], []
clf_test_counter = [idx*iterations*k_clf*target_train_loader.batch_size for idx in range(0, epochs+1)]

# %%
test_loss, test_accuracy = 0, 0
clf.eval()
tqdm_bar = tqdm(target_test_loader, desc=f'Testing ', total=int(len(target_test_loader)))

for idx, (images, labels) in enumerate(tqdm_bar):
    images, labels = images.to(device), labels.to(device)
    with torch.no_grad():
        outputs = clf(images)
        loss = criterion_test(outputs, labels)
    test_loss += loss.item()
    outputs = torch.argmax(outputs, dim=1).type(torch.FloatTensor).to(device)
    test_accuracy += torch.mean((outputs == labels).type(torch.FloatTensor)).item()
    tqdm_bar.set_postfix(test_loss=(test_loss/(idx+1)), test_accuracy=test_accuracy/(idx+1))
    # _,predicted = torch.max(outputs,axis = 1)
    # test_accuracy += torch.mean((predicted == labels).type(torch.FloatTensor)).item()
    # tqdm_bar.set_postfix(test_loss=(test_loss/(idx+1)), test_accuracy=test_accuracy/(idx+1))
  
clf_losses.append(test_loss/len(target_test_loader))
clf_accuracies.append(test_accuracy/len(target_test_loader))
# Out:
# Testing : 100%|██████████| 8/8 [00:00<00:00, 75.79it/s, test_accuracy=0.742, test_loss=0.606]

# %%
from utils import loop_iterable, load_resnet18_by_featureExtractor_classifier

for epoch in range(epochs):
    target_batch_iterator = loop_iterable(target_train_loader)
    batch_iterator = zip(loop_iterable(source_loader), loop_iterable(target_train_loader))
    disc_loss, disc_accuracy = 0, 0
    clf_disc_loss = 0
    test_loss, test_accuracy = 0, 0
    tqdm_bar = tqdm(range(iterations), desc=f'Training Epoch {epoch} ', total=iterations)
    for iter_idx in tqdm_bar:
        # Train discriminator
        set_requires_grad(target_feature_extractor, requires_grad=False)
        set_requires_grad(discriminator, requires_grad=True)
        for disc_idx in range(k_disc):
            (source_x, _), (target_x, _) = next(batch_iterator)
            source_x, target_x = source_x.to(device), target_x.to(device)
            source_features = source_feature_extractor(source_x)
            target_features = target_feature_extractor(target_x)
            discriminator_x = torch.cat([source_features, target_features])
            discriminator_y = torch.cat([torch.ones(source_x.shape[0], device=device), torch.zeros(target_x.shape[0], device=device)])
            preds = discriminator(discriminator_x).squeeze()
            loss = criterion_train(preds, discriminator_y)
            discriminator_optim.zero_grad()
            loss.backward()
            discriminator_optim.step()
            disc_loss += loss.item()
            disc_losses.append(loss.item())
            disc_batch_accuracy = ((preds > 0).long() == discriminator_y.long()).float().mean().item()
            disc_accuracy += disc_batch_accuracy
            disc_accuracies.append(disc_batch_accuracy)
            disc_train_counter.append((disc_idx+1)*source_x.size(0) + iter_idx*k_disc*target_train_loader.batch_size + epoch*iterations*k_disc*target_train_loader.batch_size)

        # Train classifier
        set_requires_grad(target_feature_extractor, requires_grad=True)
        set_requires_grad(discriminator, requires_grad=False)
        for clf_idx in range(k_clf):
            _, (target_x, _) = next(batch_iterator)
            target_x = target_x.to(device)
            target_features = target_feature_extractor(target_x).view(target_x.shape[0], -1)
            # Flipped Labels
            discriminator_y = torch.ones(target_x.shape[0], device=device)
            preds = discriminator(target_features).squeeze()
            loss = criterion_train(preds, discriminator_y)
            target_optim.zero_grad()
            loss.backward()
            target_optim.step()
            clf_disc_loss += loss.item()
            clf_disc_losses.append(loss.item())
            clf_disc_train_counter.append(source_x.size(0) + clf_idx*half_batch + iter_idx*k_clf*half_batch + epoch*iterations*k_clf*half_batch)
        tqdm_bar.set_postfix(disc_loss=disc_loss/((iter_idx+1)*k_disc), disc_accuracy=disc_accuracy/((iter_idx+1)*k_disc),
                             clf_disc_loss=clf_disc_loss/((iter_idx+1)*k_clf))

    # Test full target model
    test_loss, test_accuracy = 0, 0
    clf = load_resnet18_by_featureExtractor_classifier(target_feature_extractor,target_classifier)
    clf.eval()
    tqdm_bar = tqdm(target_test_loader, desc=f'Testing Epoch {epoch} (Full Target Model)', total=int(len(target_test_loader)))
    for idx, (images, labels) in enumerate(tqdm_bar):
        images, labels = images.to(device), labels.to(device)
        with torch.no_grad():
            outputs = clf(images)
            loss = criterion_test(outputs, labels)
        test_loss += loss.item()
        outputs = torch.argmax(outputs, dim=1).type(torch.FloatTensor).to(device)
        test_accuracy += torch.mean((outputs == labels).type(torch.FloatTensor)).item()
        tqdm_bar.set_postfix(test_loss=(test_loss/(idx+1)), test_accuracy=test_accuracy/(idx+1))
    clf_losses.append(test_loss/len(target_test_loader))
    clf_accuracies.append(test_accuracy/len(target_test_loader))
    if np.argmax(clf_accuracies) == len(clf_accuracies)-1:
        print(clf_accuracies[-1])
        torch.save(clf.state_dict(), output_path+'/adda_target_weights.pth')
# Out:
# Training Epoch 0 : 100%|██████████| 10/10 [00:03<00:00,  2.98it/s, clf_disc_loss=0.679, disc_accuracy=0.652, disc_loss=0.649]
# Testing Epoch 0 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.36it/s, test_accuracy=0.875, test_loss=0.706]
# Training Epoch 1 : 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, clf_disc_loss=0.704, disc_accuracy=0.586, disc_loss=0.649]
# Testing Epoch 1 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.97it/s, test_accuracy=0.594, test_loss=1.92]
# Training Epoch 2 : 100%|██████████| 10/10 [00:03<00:00,  3.09it/s, clf_disc_loss=0.81, disc_accuracy=0.749, disc_loss=0.575]
# Testing Epoch 2 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 77.79it/s, test_accuracy=0.844, test_loss=0.694]
# Training Epoch 3 : 100%|██████████| 10/10 [00:03<00:00,  3.20it/s, clf_disc_loss=0.806, disc_accuracy=0.836, disc_loss=0.525]
# Testing Epoch 3 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.59it/s, test_accuracy=0.875, test_loss=0.389]
# Training Epoch 4 : 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, clf_disc_loss=0.834, disc_accuracy=0.812, disc_loss=0.475]
# Testing Epoch 4 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.09it/s, test_accuracy=0.742, test_loss=0.532]
# Training Epoch 5 : 100%|██████████| 10/10 [00:03<00:00,  2.89it/s, clf_disc_loss=0.82, disc_accuracy=0.868, disc_loss=0.466]
# Testing Epoch 5 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.20it/s, test_accuracy=0.891, test_loss=0.404]
# Training Epoch 6 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=0.946, disc_accuracy=0.835, disc_loss=0.482]
# Testing Epoch 6 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.79it/s, test_accuracy=0.898, test_loss=0.452]
# Training Epoch 7 : 100%|██████████| 10/10 [00:03<00:00,  2.89it/s, clf_disc_loss=1.07, disc_accuracy=0.88, disc_loss=0.447]
# Testing Epoch 7 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.06it/s, test_accuracy=0.906, test_loss=0.341]
# Training Epoch 8 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.13, disc_accuracy=0.848, disc_loss=0.469]
# Testing Epoch 8 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.05it/s, test_accuracy=0.898, test_loss=0.332]
# Training Epoch 9 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.03, disc_accuracy=0.834, disc_loss=0.481]
# Testing Epoch 9 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.14it/s, test_accuracy=0.703, test_loss=3.15]
# Training Epoch 10 : 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, clf_disc_loss=1.11, disc_accuracy=0.779, disc_loss=0.523]
# Testing Epoch 10 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.41it/s, test_accuracy=0.93, test_loss=0.361]
# Training Epoch 11 : 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, clf_disc_loss=1.08, disc_accuracy=0.786, disc_loss=0.535]
# Testing Epoch 11 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.02it/s, test_accuracy=0.812, test_loss=1.67]
# Training Epoch 12 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.12, disc_accuracy=0.766, disc_loss=0.527]
# Testing Epoch 12 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.92it/s, test_accuracy=0.922, test_loss=0.503]
# Training Epoch 13 : 100%|██████████| 10/10 [00:03<00:00,  2.92it/s, clf_disc_loss=1.1, disc_accuracy=0.729, disc_loss=0.591]
# Testing Epoch 13 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.75it/s, test_accuracy=0.875, test_loss=0.733]
# Training Epoch 14 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.12, disc_accuracy=0.761, disc_loss=0.537]
# Testing Epoch 14 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.19it/s, test_accuracy=0.891, test_loss=0.813]
# Training Epoch 15 : 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, clf_disc_loss=1.13, disc_accuracy=0.754, disc_loss=0.535]
# Testing Epoch 15 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.77it/s, test_accuracy=0.703, test_loss=2.29]
# Training Epoch 16 : 100%|██████████| 10/10 [00:03<00:00,  2.92it/s, clf_disc_loss=1.11, disc_accuracy=0.75, disc_loss=0.561]
# Testing Epoch 16 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 78.24it/s, test_accuracy=0.906, test_loss=0.48]
# Training Epoch 17 : 100%|██████████| 10/10 [00:03<00:00,  2.86it/s, clf_disc_loss=1.12, disc_accuracy=0.708, disc_loss=0.59]
# Testing Epoch 17 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.29it/s, test_accuracy=0.875, test_loss=1.16]
# Training Epoch 18 : 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, clf_disc_loss=1.13, disc_accuracy=0.702, disc_loss=0.574]
# Testing Epoch 18 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.22it/s, test_accuracy=0.859, test_loss=1.01]
# Training Epoch 19 : 100%|██████████| 10/10 [00:03<00:00,  2.71it/s, clf_disc_loss=1.06, disc_accuracy=0.731, disc_loss=0.554]
# Testing Epoch 19 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 76.32it/s, test_accuracy=0.766, test_loss=2.06]
# Training Epoch 20 : 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, clf_disc_loss=1.16, disc_accuracy=0.699, disc_loss=0.561]
# Testing Epoch 20 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.85it/s, test_accuracy=0.633, test_loss=3.22]
# Training Epoch 21 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.16, disc_accuracy=0.78, disc_loss=0.5]
# Testing Epoch 21 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 67.06it/s, test_accuracy=0.703, test_loss=2.43]
# Training Epoch 22 : 100%|██████████| 10/10 [00:03<00:00,  3.01it/s, clf_disc_loss=1.1, disc_accuracy=0.757, disc_loss=0.517]
# Testing Epoch 22 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 74.50it/s, test_accuracy=0.852, test_loss=0.869]
# Training Epoch 23 : 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, clf_disc_loss=1.18, disc_accuracy=0.752, disc_loss=0.548]
# Testing Epoch 23 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.26it/s, test_accuracy=0.844, test_loss=1.19]
# Training Epoch 24 : 100%|██████████| 10/10 [00:03<00:00,  2.88it/s, clf_disc_loss=1.12, disc_accuracy=0.707, disc_loss=0.55]
# Testing Epoch 24 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.61it/s, test_accuracy=0.727, test_loss=3.15]
# Training Epoch 25 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.06, disc_accuracy=0.753, disc_loss=0.562]
# Testing Epoch 25 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.86it/s, test_accuracy=0.898, test_loss=0.61]
# Training Epoch 26 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.14, disc_accuracy=0.727, disc_loss=0.585]
# Testing Epoch 26 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.29it/s, test_accuracy=0.789, test_loss=1.98]
# Training Epoch 27 : 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, clf_disc_loss=1.01, disc_accuracy=0.677, disc_loss=0.579]
# Testing Epoch 27 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.17it/s, test_accuracy=0.828, test_loss=1.53]
# Training Epoch 28 : 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, clf_disc_loss=1.16, disc_accuracy=0.678, disc_loss=0.591]
# Testing Epoch 28 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.97it/s, test_accuracy=0.891, test_loss=0.763]
# Training Epoch 29 : 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, clf_disc_loss=1.12, disc_accuracy=0.794, disc_loss=0.526]
# Testing Epoch 29 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.09it/s, test_accuracy=0.875, test_loss=0.747]
# Training Epoch 30 : 100%|██████████| 10/10 [00:03<00:00,  2.82it/s, clf_disc_loss=1.07, disc_accuracy=0.736, disc_loss=0.568]
# Testing Epoch 30 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.23it/s, test_accuracy=0.906, test_loss=0.784]
# Training Epoch 31 : 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, clf_disc_loss=1.06, disc_accuracy=0.74, disc_loss=0.582]
# Testing Epoch 31 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 57.73it/s, test_accuracy=0.906, test_loss=0.963]
# Training Epoch 32 : 100%|██████████| 10/10 [00:03<00:00,  2.78it/s, clf_disc_loss=1.13, disc_accuracy=0.736, disc_loss=0.578]
# Testing Epoch 32 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 57.80it/s, test_accuracy=0.867, test_loss=0.91]
# Training Epoch 33 : 100%|██████████| 10/10 [00:03<00:00,  2.85it/s, clf_disc_loss=1.12, disc_accuracy=0.777, disc_loss=0.534]
# Testing Epoch 33 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 78.25it/s, test_accuracy=0.891, test_loss=0.726]
# Training Epoch 34 : 100%|██████████| 10/10 [00:03<00:00,  2.89it/s, clf_disc_loss=1.05, disc_accuracy=0.757, disc_loss=0.538]
# Testing Epoch 34 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 58.15it/s, test_accuracy=0.883, test_loss=0.975]
# Training Epoch 35 : 100%|██████████| 10/10 [00:03<00:00,  2.85it/s, clf_disc_loss=1.13, disc_accuracy=0.728, disc_loss=0.577]
# Testing Epoch 35 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 57.80it/s, test_accuracy=0.914, test_loss=0.556]
# Training Epoch 36 : 100%|██████████| 10/10 [00:03<00:00,  2.80it/s, clf_disc_loss=0.994, disc_accuracy=0.758, disc_loss=0.57]
# Testing Epoch 36 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 57.58it/s, test_accuracy=0.914, test_loss=0.794]
# Training Epoch 37 : 100%|██████████| 10/10 [00:03<00:00,  2.86it/s, clf_disc_loss=1.04, disc_accuracy=0.757, disc_loss=0.556]
# Testing Epoch 37 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.41it/s, test_accuracy=0.93, test_loss=0.418]
# Training Epoch 38 : 100%|██████████| 10/10 [00:03<00:00,  3.20it/s, clf_disc_loss=1.05, disc_accuracy=0.768, disc_loss=0.547]
# Testing Epoch 38 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.93it/s, test_accuracy=0.914, test_loss=0.831]
# Training Epoch 39 : 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, clf_disc_loss=1.18, disc_accuracy=0.734, disc_loss=0.556]
# Testing Epoch 39 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.95it/s, test_accuracy=0.906, test_loss=0.854]
# Training Epoch 40 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.06, disc_accuracy=0.767, disc_loss=0.54]
# Testing Epoch 40 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.04it/s, test_accuracy=0.883, test_loss=1.13]
# Training Epoch 41 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.09, disc_accuracy=0.654, disc_loss=0.631]
# Testing Epoch 41 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.37it/s, test_accuracy=0.898, test_loss=0.948]
# Training Epoch 42 : 100%|██████████| 10/10 [00:03<00:00,  2.98it/s, clf_disc_loss=1.13, disc_accuracy=0.746, disc_loss=0.554]
# Testing Epoch 42 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.53it/s, test_accuracy=0.914, test_loss=0.701]
# Training Epoch 43 : 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, clf_disc_loss=1.06, disc_accuracy=0.748, disc_loss=0.543]
# Testing Epoch 43 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.40it/s, test_accuracy=0.906, test_loss=0.744]
# Training Epoch 44 : 100%|██████████| 10/10 [00:03<00:00,  3.01it/s, clf_disc_loss=1.05, disc_accuracy=0.71, disc_loss=0.573]
# Testing Epoch 44 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 69.19it/s, test_accuracy=0.906, test_loss=0.963]
# Training Epoch 45 : 100%|██████████| 10/10 [00:03<00:00,  3.24it/s, clf_disc_loss=1.11, disc_accuracy=0.69, disc_loss=0.587]
# Testing Epoch 45 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.22it/s, test_accuracy=0.875, test_loss=1.34]
# Training Epoch 46 : 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, clf_disc_loss=1.18, disc_accuracy=0.707, disc_loss=0.552]
# Testing Epoch 46 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.12it/s, test_accuracy=0.93, test_loss=0.705]
# Training Epoch 47 : 100%|██████████| 10/10 [00:03<00:00,  3.31it/s, clf_disc_loss=1.17, disc_accuracy=0.726, disc_loss=0.568]
# Testing Epoch 47 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.56it/s, test_accuracy=0.836, test_loss=1.4]
# Training Epoch 48 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.11, disc_accuracy=0.721, disc_loss=0.549]
# Testing Epoch 48 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.51it/s, test_accuracy=0.859, test_loss=1.11]
# Training Epoch 49 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.03, disc_accuracy=0.728, disc_loss=0.574]
# Testing Epoch 49 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.71it/s, test_accuracy=0.914, test_loss=0.855]
# Training Epoch 50 : 100%|██████████| 10/10 [00:03<00:00,  2.92it/s, clf_disc_loss=1.11, disc_accuracy=0.728, disc_loss=0.554]
# Testing Epoch 50 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.21it/s, test_accuracy=0.867, test_loss=1.35]
# Training Epoch 51 : 100%|██████████| 10/10 [00:03<00:00,  2.99it/s, clf_disc_loss=1.09, disc_accuracy=0.745, disc_loss=0.548]
# Testing Epoch 51 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.52it/s, test_accuracy=0.914, test_loss=0.772]
# Training Epoch 52 : 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, clf_disc_loss=1.12, disc_accuracy=0.685, disc_loss=0.601]
# Testing Epoch 52 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.92it/s, test_accuracy=0.906, test_loss=0.743]
# Training Epoch 53 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.12, disc_accuracy=0.726, disc_loss=0.577]
# Testing Epoch 53 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 76.23it/s, test_accuracy=0.898, test_loss=1.27]
# Training Epoch 54 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.24, disc_accuracy=0.778, disc_loss=0.516]
# Testing Epoch 54 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.24it/s, test_accuracy=0.906, test_loss=0.856]
# Training Epoch 55 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1, disc_accuracy=0.713, disc_loss=0.566]
# Testing Epoch 55 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.39it/s, test_accuracy=0.906, test_loss=0.908]
# Training Epoch 56 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.1, disc_accuracy=0.742, disc_loss=0.554]
# Testing Epoch 56 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 59.84it/s, test_accuracy=0.812, test_loss=1.52]
# Training Epoch 57 : 100%|██████████| 10/10 [00:03<00:00,  2.87it/s, clf_disc_loss=1.03, disc_accuracy=0.711, disc_loss=0.573]
# Testing Epoch 57 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.22it/s, test_accuracy=0.797, test_loss=0.989]
# Training Epoch 58 : 100%|██████████| 10/10 [00:03<00:00,  2.88it/s, clf_disc_loss=1.08, disc_accuracy=0.711, disc_loss=0.564]
# Testing Epoch 58 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.44it/s, test_accuracy=0.883, test_loss=1.06]
# Training Epoch 59 : 100%|██████████| 10/10 [00:03<00:00,  2.80it/s, clf_disc_loss=1.13, disc_accuracy=0.754, disc_loss=0.539]
# Testing Epoch 59 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.46it/s, test_accuracy=0.898, test_loss=0.874]
# Training Epoch 60 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.08, disc_accuracy=0.738, disc_loss=0.568]
# Testing Epoch 60 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.88it/s, test_accuracy=0.844, test_loss=1.08]
# Training Epoch 61 : 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, clf_disc_loss=1.14, disc_accuracy=0.76, disc_loss=0.541]
# Testing Epoch 61 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 66.51it/s, test_accuracy=0.906, test_loss=0.706]
# Training Epoch 62 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.14, disc_accuracy=0.719, disc_loss=0.564]
# Testing Epoch 62 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.74it/s, test_accuracy=0.914, test_loss=0.7]
# Training Epoch 63 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.06, disc_accuracy=0.744, disc_loss=0.549]
# Testing Epoch 63 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.67it/s, test_accuracy=0.773, test_loss=2.45]
# Training Epoch 64 : 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, clf_disc_loss=1.15, disc_accuracy=0.737, disc_loss=0.535]
# Testing Epoch 64 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 69.75it/s, test_accuracy=0.828, test_loss=1.37]
# Training Epoch 65 : 100%|██████████| 10/10 [00:03<00:00,  3.06it/s, clf_disc_loss=1.15, disc_accuracy=0.734, disc_loss=0.551]
# Testing Epoch 65 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.46it/s, test_accuracy=0.891, test_loss=1.24]
# Training Epoch 66 : 100%|██████████| 10/10 [00:03<00:00,  3.11it/s, clf_disc_loss=1.18, disc_accuracy=0.743, disc_loss=0.555]
# Testing Epoch 66 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.70it/s, test_accuracy=0.906, test_loss=0.999]
# Training Epoch 67 : 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, clf_disc_loss=1.17, disc_accuracy=0.754, disc_loss=0.535]
# Testing Epoch 67 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 78.34it/s, test_accuracy=0.867, test_loss=1.54]
# Training Epoch 68 : 100%|██████████| 10/10 [00:03<00:00,  3.28it/s, clf_disc_loss=1.1, disc_accuracy=0.738, disc_loss=0.524]
# Testing Epoch 68 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.52it/s, test_accuracy=0.859, test_loss=0.952]
# Training Epoch 69 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.1, disc_accuracy=0.747, disc_loss=0.539]
# Testing Epoch 69 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.70it/s, test_accuracy=0.891, test_loss=0.926]
# Training Epoch 70 : 100%|██████████| 10/10 [00:03<00:00,  2.99it/s, clf_disc_loss=1.23, disc_accuracy=0.726, disc_loss=0.546]
# Testing Epoch 70 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.35it/s, test_accuracy=0.844, test_loss=1.07]
# Training Epoch 71 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.37, disc_accuracy=0.743, disc_loss=0.53]
# Testing Epoch 71 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.27it/s, test_accuracy=0.906, test_loss=0.753]
# Training Epoch 72 : 100%|██████████| 10/10 [00:03<00:00,  3.00it/s, clf_disc_loss=1.09, disc_accuracy=0.772, disc_loss=0.509]
# Testing Epoch 72 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.41it/s, test_accuracy=0.914, test_loss=0.635]
# Training Epoch 73 : 100%|██████████| 10/10 [00:03<00:00,  2.80it/s, clf_disc_loss=1.18, disc_accuracy=0.701, disc_loss=0.573]
# Testing Epoch 73 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.11it/s, test_accuracy=0.828, test_loss=1.99]
# Training Epoch 74 : 100%|██████████| 10/10 [00:03<00:00,  3.01it/s, clf_disc_loss=1.17, disc_accuracy=0.766, disc_loss=0.518]
# Testing Epoch 74 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 76.10it/s, test_accuracy=0.914, test_loss=0.585]
# Training Epoch 75 : 100%|██████████| 10/10 [00:03<00:00,  3.10it/s, clf_disc_loss=1.17, disc_accuracy=0.761, disc_loss=0.533]
# Testing Epoch 75 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.66it/s, test_accuracy=0.883, test_loss=1.48]
# Training Epoch 76 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.14, disc_accuracy=0.742, disc_loss=0.53]
# Testing Epoch 76 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.18it/s, test_accuracy=0.938, test_loss=0.805]
# Training Epoch 77 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.08, disc_accuracy=0.72, disc_loss=0.546]
# Testing Epoch 77 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.75it/s, test_accuracy=0.938, test_loss=0.881]
# Training Epoch 78 : 100%|██████████| 10/10 [00:02<00:00,  3.34it/s, clf_disc_loss=1.14, disc_accuracy=0.75, disc_loss=0.533]
# Testing Epoch 78 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.68it/s, test_accuracy=0.938, test_loss=0.744]
# Training Epoch 79 : 100%|██████████| 10/10 [00:03<00:00,  3.15it/s, clf_disc_loss=1.15, disc_accuracy=0.72, disc_loss=0.556]
# Testing Epoch 79 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.48it/s, test_accuracy=0.914, test_loss=0.75]
# Training Epoch 80 : 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, clf_disc_loss=1.25, disc_accuracy=0.761, disc_loss=0.526]
# Testing Epoch 80 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.04it/s, test_accuracy=0.602, test_loss=4.58]
# Training Epoch 81 : 100%|██████████| 10/10 [00:03<00:00,  3.20it/s, clf_disc_loss=1.37, disc_accuracy=0.821, disc_loss=0.425]
# Testing Epoch 81 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.10it/s, test_accuracy=0.672, test_loss=3.78]
# Training Epoch 82 : 100%|██████████| 10/10 [00:03<00:00,  3.28it/s, clf_disc_loss=1.36, disc_accuracy=0.828, disc_loss=0.414]
# Testing Epoch 82 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 65.09it/s, test_accuracy=0.617, test_loss=3.7]
# Training Epoch 83 : 100%|██████████| 10/10 [00:03<00:00,  3.03it/s, clf_disc_loss=1.28, disc_accuracy=0.79, disc_loss=0.457]
# Testing Epoch 83 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.58it/s, test_accuracy=0.641, test_loss=4.25]
# Training Epoch 84 : 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, clf_disc_loss=1.32, disc_accuracy=0.798, disc_loss=0.438]
# Testing Epoch 84 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 80.57it/s, test_accuracy=0.641, test_loss=4.79]
# Training Epoch 85 : 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, clf_disc_loss=1.32, disc_accuracy=0.798, disc_loss=0.459]
# Testing Epoch 85 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.61it/s, test_accuracy=0.75, test_loss=2.43]
# Training Epoch 86 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.27, disc_accuracy=0.755, disc_loss=0.539]
# Testing Epoch 86 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.46it/s, test_accuracy=0.93, test_loss=0.64]
# Training Epoch 87 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.27, disc_accuracy=0.773, disc_loss=0.496]
# Testing Epoch 87 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.97it/s, test_accuracy=0.617, test_loss=4.51]
# Training Epoch 88 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.28, disc_accuracy=0.789, disc_loss=0.461]
# Testing Epoch 88 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.65it/s, test_accuracy=0.641, test_loss=4.48]
# Training Epoch 89 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.19, disc_accuracy=0.776, disc_loss=0.468]
# Testing Epoch 89 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.99it/s, test_accuracy=0.641, test_loss=4.31]
# Training Epoch 90 : 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, clf_disc_loss=1.24, disc_accuracy=0.732, disc_loss=0.498]
# Testing Epoch 90 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 64.27it/s, test_accuracy=0.617, test_loss=5.93]
# Training Epoch 91 : 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, clf_disc_loss=1.34, disc_accuracy=0.784, disc_loss=0.455]
# Testing Epoch 91 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.71it/s, test_accuracy=0.602, test_loss=6.16]
# Training Epoch 92 : 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, clf_disc_loss=1.28, disc_accuracy=0.769, disc_loss=0.468]
# Testing Epoch 92 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 61.60it/s, test_accuracy=0.633, test_loss=4.38]
# Training Epoch 93 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.38, disc_accuracy=0.802, disc_loss=0.434]
# Testing Epoch 93 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.60it/s, test_accuracy=0.648, test_loss=4.19]
# Training Epoch 94 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.43, disc_accuracy=0.788, disc_loss=0.429]
# Testing Epoch 94 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.21it/s, test_accuracy=0.57, test_loss=5.22]
# Training Epoch 95 : 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, clf_disc_loss=1.26, disc_accuracy=0.761, disc_loss=0.459]
# Testing Epoch 95 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 61.99it/s, test_accuracy=0.672, test_loss=4.86]
# Training Epoch 96 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.35, disc_accuracy=0.798, disc_loss=0.436]
# Testing Epoch 96 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.03it/s, test_accuracy=0.672, test_loss=3.19]
# Training Epoch 97 : 100%|██████████| 10/10 [00:03<00:00,  2.99it/s, clf_disc_loss=1.35, disc_accuracy=0.814, disc_loss=0.42]
# Testing Epoch 97 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 62.95it/s, test_accuracy=0.672, test_loss=4.09]
# Training Epoch 98 : 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, clf_disc_loss=1.38, disc_accuracy=0.808, disc_loss=0.429]
# Testing Epoch 98 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 70.29it/s, test_accuracy=0.664, test_loss=5.07]
# Training Epoch 99 : 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, clf_disc_loss=1.39, disc_accuracy=0.778, disc_loss=0.442]
# Testing Epoch 99 (Full Target Model): 100%|██████████| 8/8 [00:00<00:00, 63.85it/s, test_accuracy=0.648, test_loss=4.47]

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
import plotly.graph_objects as go
import plotly.subplots as sp
fig = sp.make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=disc_train_counter, y=disc_losses, mode='lines', name='Disc Loss'), secondary_y=False)
fig.add_trace(go.Scatter(x=disc_train_counter, y=disc_accuracies, mode='lines', name='Disc Accuracy', line_color='lightseagreen'), secondary_y=True)
fig.update_layout(
    width=1000,
    height=500,
    title="Discriminator Loss vs Accuracy")
fig.update_xaxes(title_text="Number of training examples seen")
fig.update_yaxes(title_text="Discriminator <b>Loss</b> (BCE)", secondary_y=False)
fig.update_yaxes(title_text="Discriminator <b>Accuracy</b>", secondary_y=True)
fig.show()
fig.write_image(output_path+"/Discriminator_loss_accuracy.pdf")

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Number of training examples seen': disc_train_counter,
    'Disc Loss': disc_losses,
    'Disc Accuracy': disc_accuracies
}

df = pd.DataFrame(data)
fig, ax1 = plt.subplots(figsize=(10, 5))
sns.lineplot(data=df, x='Number of training examples seen', y='Disc Loss', ax=ax1, label='Disc Loss')
ax1.set_xlabel('Number of training examples seen')
ax1.set_ylabel('Discriminator Loss (BCE)', color='tab:blue')
ax2 = ax1.twinx()
sns.lineplot(data=df, x='Number of training examples seen', y='Disc Accuracy', ax=ax2, color='lightseagreen', label='Disc Accuracy')
ax2.set_ylabel('Discriminator Accuracy', color='lightseagreen')
fig.suptitle("Discriminator Loss vs Accuracy")


plt.savefig(output_path+"/Discriminator_loss_accuracy.eps", format='eps', bbox_inches='tight')
plt.savefig(output_path+"/Discriminator_loss_accuracy.png", format='png', bbox_inches='tight',dpi=300)
plt.show()
# Out:
# <div>                            <div id="dc776b08-840e-4288-b492-ccd108950943" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc776b08-840e-4288-b492-ccd108950943")) {                    Plotly.newPlot(                        "dc776b08-840e-4288-b492-ccd108950943",                        [{"mode":"lines","name":"Disc Loss","x":[8,16,24,32,40,48,56,64,72,80,88,96,104,112,120,128,136,144,152,160,164,176,184,192,200,208,216,224,232,240,248,256,264,272,280,288,296,304,312,320,328,328,344,352,360,368,376,384,392,400,408,416,424,432,440,448,456,464,472,480,488,496,492,512,520,528,536,544,552,560,568,576,584,592,600,608,616,624,632,640,648,656,664,656,680,688,696,704,712,720,728,736,744,752,760,768,776,784,792,800,808,816,824,832,840,848,856,864,872,880,888,896,904,912,920,928,936,944,952,960,964,976,984,992,1000,1008,1016,1024,1032,1040,1048,1056,1064,1072,1080,1088,1096,1104,1112,1120,1128,1128,1144,1152,1160,1168,1176,1184,1192,1200,1208,1216,1224,1232,1240,1248,1256,1264,1272,1280,1288,1296,1292,1312,1320,1328,1336,1344,1352,1360,1368,1376,1384,1392,1400,1408,1416,1424,1432,1440,1448,1456,1464,1456,1480,1488,1496,1504,1512,1520,1528,1536,1544,1552,1560,1568,1576,1584,1592,1600,1608,1616,1624,1632,1640,1648,1656,1664,1672,1680,1688,1696,1704,1712,1720,1728,1736,1744,1752,1760,1764,1776,1784,1792,1800,1808,1816,1824,1832,1840,1848,1856,1864,1872,1880,1888,1896,1904,1912,1920,1928,1928,1944,1952,1960,1968,1976,1984,1992,2000,2008,2016,2024,2032,2040,2048,2056,2064,2072,2080,2088,2096,2092,2112,2120,2128,2136,2144,2152,2160,2168,2176,2184,2192,2200,2208,2216,2224,2232,2240,2248,2256,2264,2256,2280,2288,2296,2304,2312,2320,2328,2336,2344,2352,2360,2368,2376,2384,2392,2400,2408,2416,2424,2432,2440,2448,2456,2464,2472,2480,2488,2496,2504,2512,2520,2528,2536,2544,2552,2560,2564,2576,2584,2592,2600,2608,2616,2624,2632,2640,2648,2656,2664,2672,2680,2688,2696,2704,2712,2720,2728,2728,2744,2752,2760,2768,2776,2784,2792,2800,2808,2816,2824,2832,2840,2848,2856,2864,2872,2880,2888,2896,2892,2912,2920,2928,2936,2944,2952,2960,2968,2976,2984,2992,3000,3008,3016,3024,3032,3040,3048,3056,3064,3056,3080,3088,3096,3104,3112,3120,3128,3136,3144,3152,3160,3168,3176,3184,3192,3200,3208,3216,3224,3232,3240,3248,3256,3264,3272,3280,3288,3296,3304,3312,3320,3328,3336,3344,3352,3360,3364,3376,3384,3392,3400,3408,3416,3424,3432,3440,3448,3456,3464,3472,3480,3488,3496,3504,3512,3520,3528,3528,3544,3552,3560,3568,3576,3584,3592,3600,3608,3616,3624,3632,3640,3648,3656,3664,3672,3680,3688,3696,3692,3712,3720,3728,3736,3744,3752,3760,3768,3776,3784,3792,3800,3808,3816,3824,3832,3840,3848,3856,3864,3856,3880,3888,3896,3904,3912,3920,3928,3936,3944,3952,3960,3968,3976,3984,3992,4000,4008,4016,4024,4032,4040,4048,4056,4064,4072,4080,4088,4096,4104,4112,4120,4128,4136,4144,4152,4160,4164,4176,4184,4192,4200,4208,4216,4224,4232,4240,4248,4256,4264,4272,4280,4288,4296,4304,4312,4320,4328,4328,4344,4352,4360,4368,4376,4384,4392,4400,4408,4416,4424,4432,4440,4448,4456,4464,4472,4480,4488,4496,4492,4512,4520,4528,4536,4544,4552,4560,4568,4576,4584,4592,4600,4608,4616,4624,4632,4640,4648,4656,4664,4656,4680,4688,4696,4704,4712,4720,4728,4736,4744,4752,4760,4768,4776,4784,4792,4800,4808,4816,4824,4832,4840,4848,4856,4864,4872,4880,4888,4896,4904,4912,4920,4928,4936,4944,4952,4960,4964,4976,4984,4992,5000,5008,5016,5024,5032,5040,5048,5056,5064,5072,5080,5088,5096,5104,5112,5120,5128,5128,5144,5152,5160,5168,5176,5184,5192,5200,5208,5216,5224,5232,5240,5248,5256,5264,5272,5280,5288,5296,5292,5312,5320,5328,5336,5344,5352,5360,5368,5376,5384,5392,5400,5408,5416,5424,5432,5440,5448,5456,5464,5456,5480,5488,5496,5504,5512,5520,5528,5536,5544,5552,5560,5568,5576,5584,5592,5600,5608,5616,5624,5632,5640,5648,5656,5664,5672,5680,5688,5696,5704 ...
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=clf_disc_train_counter, y=clf_disc_losses, mode='lines', name='Clf-Disc Train Loss'))
fig.update_layout(
    width=1000,
    height=500,
    title="Clf-Disc Loss",
    xaxis_title="Number of training examples seen",
    yaxis_title="Binary Cross Entropy Loss"),
fig.show()
fig.write_image(output_path+"/Clf-Disc Loss.pdf")

data = {
    'Number of training examples seen': clf_disc_train_counter,
    'Clf-Disc Train Loss': clf_disc_losses
}

df = pd.DataFrame(data)
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='Number of training examples seen', y='Clf-Disc Train Loss', label='Clf-Disc Train Loss')
plt.title("Clf-Disc Loss")
plt.xlabel("Number of training examples seen")
plt.ylabel("Binary Cross Entropy Loss")
plt.savefig(output_path+"/Clf-Disc Loss.eps", format='eps', bbox_inches='tight')
plt.savefig(output_path+"/Clf-Disc Loss.png", format='png', bbox_inches='tight',dpi=300)
plt.show()
# Out:
# <div>                            <div id="ce31673c-b2ee-40f1-8039-ed54aec71067" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce31673c-b2ee-40f1-8039-ed54aec71067")) {                    Plotly.newPlot(                        "ce31673c-b2ee-40f1-8039-ed54aec71067",                        [{"mode":"lines","name":"Clf-Disc Train Loss","x":[8,16,24,32,40,48,56,64,72,80,88,96,104,112,120,128,136,144,152,160,168,176,184,192,200,208,216,224,232,240,248,256,264,272,280,288,296,304,312,320,328,336,344,352,360,368,376,384,392,400,408,416,424,432,440,448,456,464,472,480,488,496,504,512,520,528,536,544,552,560,568,576,584,592,600,608,616,624,632,640,648,656,664,672,680,688,696,704,712,720,728,736,744,752,760,768,776,784,792,800,808,816,824,832,840,848,856,864,872,880,888,896,904,912,920,928,936,944,952,960,968,976,984,992,1000,1008,1016,1024,1032,1040,1048,1056,1064,1072,1080,1088,1096,1104,1112,1120,1128,1136,1144,1152,1160,1168,1176,1184,1192,1200,1208,1216,1224,1232,1240,1248,1256,1264,1272,1280,1288,1296,1304,1312,1320,1328,1336,1344,1352,1360,1368,1376,1384,1392,1400,1408,1416,1424,1432,1440,1448,1456,1464,1472,1480,1488,1496,1504,1512,1520,1528,1536,1544,1552,1560,1568,1576,1584,1592,1600,1608,1616,1624,1632,1640,1648,1656,1664,1672,1680,1688,1696,1704,1712,1720,1728,1736,1744,1752,1760,1768,1776,1784,1792,1800,1808,1816,1824,1832,1840,1848,1856,1864,1872,1880,1888,1896,1904,1912,1920,1928,1936,1944,1952,1960,1968,1976,1984,1992,2000,2008,2016,2024,2032,2040,2048,2056,2064,2072,2080,2088,2096,2104,2112,2120,2128,2136,2144,2152,2160,2168,2176,2184,2192,2200,2208,2216,2224,2232,2240,2248,2256,2264,2272,2280,2288,2296,2304,2312,2320,2328,2336,2344,2352,2360,2368,2376,2384,2392,2400,2408,2416,2424,2432,2440,2448,2456,2464,2472,2480,2488,2496,2504,2512,2520,2528,2536,2544,2552,2560,2568,2576,2584,2592,2600,2608,2616,2624,2632,2640,2648,2656,2664,2672,2680,2688,2696,2704,2712,2720,2728,2736,2744,2752,2760,2768,2776,2784,2792,2800,2808,2816,2824,2832,2840,2848,2856,2864,2872,2880,2888,2896,2904,2912,2920,2928,2936,2944,2952,2960,2968,2976,2984,2992,3000,3008,3016,3024,3032,3040,3048,3056,3064,3072,3080,3088,3096,3104,3112,3120,3128,3136,3144,3152,3160,3168,3176,3184,3192,3200,3208,3216,3224,3232,3240,3248,3256,3264,3272,3280,3288,3296,3304,3312,3320,3328,3336,3344,3352,3360,3368,3376,3384,3392,3400,3408,3416,3424,3432,3440,3448,3456,3464,3472,3480,3488,3496,3504,3512,3520,3528,3536,3544,3552,3560,3568,3576,3584,3592,3600,3608,3616,3624,3632,3640,3648,3656,3664,3672,3680,3688,3696,3704,3712,3720,3728,3736,3744,3752,3760,3768,3776,3784,3792,3800,3808,3816,3824,3832,3840,3848,3856,3864,3872,3880,3888,3896,3904,3912,3920,3928,3936,3944,3952,3960,3968,3976,3984,3992,4000,4008,4016,4024,4032,4040,4048,4056,4064,4072,4080,4088,4096,4104,4112,4120,4128,4136,4144,4152,4160,4168,4176,4184,4192,4200,4208,4216,4224,4232,4240,4248,4256,4264,4272,4280,4288,4296,4304,4312,4320,4328,4336,4344,4352,4360,4368,4376,4384,4392,4400,4408,4416,4424,4432,4440,4448,4456,4464,4472,4480,4488,4496,4504,4512,4520,4528,4536,4544,4552,4560,4568,4576,4584,4592,4600,4608,4616,4624,4632,4640,4648,4656,4664,4672,4680,4688,4696,4704,4712,4720,4728,4736,4744,4752,4760,4768,4776,4784,4792,4800,4808,4816,4824,4832,4840,4848,4856,4864,4872,4880,4888,4896,4904,4912,4920,4928,4936,4944,4952,4960,4968,4976,4984,4992,5000,5008,5016,5024,5032,5040,5048,5056,5064,5072,5080,5088,5096,5104,5112,5120,5128,5136,5144,5152,5160,5168,5176,5184,5192,5200,5208,5216,5224,5232,5240,5248,5256,5264,5272,5280,5288,5296,5304,5312,5320,5328,5336,5344,5352,5360,5368,5376,5384,5392,5400,5408,5416,5424,5432,5440,5448,5456,5464,5472,5480,5488,5496,5504,5512,5520,5528,5536,5544,5552,5560,5568,5576,5584,5592,5600,5608,5616,5624,5632,5640,5648,5656,5664,5672,5680,5688 ...
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import plotly
fig = plotly.subplots.make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=clf_test_counter, y=clf_accuracies, marker_symbol='star-diamond', 
                         marker_line_color="orange", marker_line_width=1, marker_size=9, mode='lines+markers', 
                         name='Target Accuracy'), secondary_y=False)
fig.add_trace(go.Scatter(x=clf_test_counter, y=clf_losses, marker_symbol='star-square', 
                         marker_line_color="lightseagreen", marker_line_width=1, marker_size=9, mode='lines+markers',
                         name='Target Loss'), secondary_y=True)
fig.update_layout(
    width=1000,
    height=500,
    title="Full Target Model Loss vs Accuracy")
fig.update_xaxes(title_text="Number of training examples seen")
fig.update_yaxes(title_text="Target <b>Accuracy</b>", secondary_y=False)
fig.update_yaxes(title_text="Target <b>Loss</b> (NLLLoss)", secondary_y=True)
fig.show()
fig.write_image(output_path+"/Target_Loss_Accuracy Loss.pdf")


import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Number of training examples seen': clf_test_counter,
    'Target Accuracy': clf_accuracies,
    'Target Loss': clf_losses
}

df = pd.DataFrame(data)
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='Number of training examples seen', y='Target Accuracy', label='Target Accuracy')
ax2 = plt.twinx()
sns.lineplot(data=df, x='Number of training examples seen', y='Target Loss', ax=ax2, color='lightseagreen', label='Target Loss')
plt.title("Full Target Model Loss vs Accuracy")
plt.xlabel("Number of training examples seen")
plt.ylabel("Target Accuracy")
ax2.set_ylabel("Target Loss (NLLLoss)", color='lightseagreen')
plt.savefig(output_path+"/Target_Loss_Accuracy Loss.eps", format='eps', bbox_inches='tight')
plt.savefig(output_path+"/Target_Loss_Accuracy.png", format='png', bbox_inches='tight',dpi=300)
plt.show()
# Out:
# <div>                            <div id="5580fe84-e196-48f1-8fc2-e19876dc4456" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5580fe84-e196-48f1-8fc2-e19876dc4456")) {                    Plotly.newPlot(                        "5580fe84-e196-48f1-8fc2-e19876dc4456",                        [{"marker":{"line":{"color":"orange","width":1},"size":9,"symbol":"star-diamond"},"mode":"lines+markers","name":"Target Accuracy","x":[0,80,160,240,320,400,480,560,640,720,800,880,960,1040,1120,1200,1280,1360,1440,1520,1600,1680,1760,1840,1920,2000,2080,2160,2240,2320,2400,2480,2560,2640,2720,2800,2880,2960,3040,3120,3200,3280,3360,3440,3520,3600,3680,3760,3840,3920,4000,4080,4160,4240,4320,4400,4480,4560,4640,4720,4800,4880,4960,5040,5120,5200,5280,5360,5440,5520,5600,5680,5760,5840,5920,6000,6080,6160,6240,6320,6400,6480,6560,6640,6720,6800,6880,6960,7040,7120,7200,7280,7360,7440,7520,7600,7680,7760,7840,7920,8000],"y":[0.7421875,0.875,0.59375,0.84375,0.875,0.7421875,0.890625,0.8984375,0.90625,0.8984375,0.703125,0.9296875,0.8125,0.921875,0.875,0.890625,0.703125,0.90625,0.875,0.859375,0.765625,0.6328125,0.703125,0.8515625,0.84375,0.7265625,0.8984375,0.7890625,0.828125,0.890625,0.875,0.90625,0.90625,0.8671875,0.890625,0.8828125,0.9140625,0.9140625,0.9296875,0.9140625,0.90625,0.8828125,0.8984375,0.9140625,0.90625,0.90625,0.875,0.9296875,0.8359375,0.859375,0.9140625,0.8671875,0.9140625,0.90625,0.8984375,0.90625,0.90625,0.8125,0.796875,0.8828125,0.8984375,0.84375,0.90625,0.9140625,0.7734375,0.828125,0.890625,0.90625,0.8671875,0.859375,0.890625,0.84375,0.90625,0.9140625,0.828125,0.9140625,0.8828125,0.9375,0.9375,0.9375,0.9140625,0.6015625,0.671875,0.6171875,0.640625,0.640625,0.75,0.9296875,0.6171875,0.640625,0.640625,0.6171875,0.6015625,0.6328125,0.6484375,0.5703125,0.671875,0.671875,0.671875,0.6640625,0.6484375],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"line":{"color":"lightseagreen","width":1},"size":9,"symbol":"star-square"},"mode":"lines+markers","name":"Target Loss","x":[0,80,160,240,320,400,480,560,640,720,800,880,960,1040,1120,1200,1280,1360,1440,1520,1600,1680,1760,1840,1920,2000,2080,2160,2240,2320,2400,2480,2560,2640,2720,2800,2880,2960,3040,3120,3200,3280,3360,3440,3520,3600,3680,3760,3840,3920,4000,4080,4160,4240,4320,4400,4480,4560,4640,4720,4800,4880,4960,5040,5120,5200,5280,5360,5440,5520,5600,5680,5760,5840,5920,6000,6080,6160,6240,6320,6400,6480,6560,6640,6720,6800,6880,6960,7040,7120,7200,7280,7360,7440,7520,7600,7680,7760,7840,7920,8000],"y":[0.6062159389257431,0.7061654381400331,1.9207265405348153,0.6939022780570667,0.3888998506590724,0.5317724719643593,0.403505957336165,0.45172575558535755,0.34072569583076984,0.33187380246818066,3.154024366289377,0.36119881180638913,1.6677437713369696,0.5025623858803101,0.7327854645756133,0.8128418051653625,2.2874225713312217,0.4802200114354491,1.1592019912040996,1.0079567331595172,2.0564231090243066,3.2172865383218436,2.434866108960705,0.8689775480888784,1.190711366944015,3.147544965147972,0.6096914313429806,1.9838321078568624,1.5306138962047269,0.7627886873356147,0.7472957328282064,0.7840690110206197,0.9627607424918097,0.9103479882833199,0.7255969173274934,0.974683788845141,0.5558935647131875,0.7935869619229052,0.4177669180501198,0.8310033076486434,0.8541627394006355,1.1291517873642078,0.948160351756087,0.7007099230384597,0.7443355184295797,0.9631296522347839,1.3414702446898357,0.7051266577980186,1.404928841848772,1.107060587106389,0.8546542476615286,1.3476933277950138,0.7724991058275918,0.7433056792942807,1.274255136923614,0.8563976343721151,0.9080793773750315,1.5159985997254353,0.9893575198948241,1.0608884923849757,0.8736436893013888,1.0791225968241633,0.7062765326190856,0.7002075081879866,2.45124029670842,1.3652519525858224,1.238061998039 ...
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
max(clf_accuracies)
# Out:
# 0.9375

# %%
from utils import feature_extractor_resnet18
import torch.nn.functional as nf

def predict_gesture(model,test_loader,device):
    predicted_list,labels_list = [],[]
    test_loss = 0.0
    test_correct = 0.0
    test_total = 0.0
    all_features = []
    with torch.no_grad():
        model.eval()
        with tqdm(test_loader,desc = 'Test') as t:
            for data in t :
                inputs ,labels = data
                inputs = inputs.to(device)
                labels = labels.to(device)
                features = feature_extractor_resnet18(model,inputs)
                all_features.append(features.cpu().numpy())
                outputs = model.forward(inputs)
                # outputs2 = model.fc(features)
                # print(torch.equal(outputs,outputs2))
                l = nf.cross_entropy(outputs,labels)
                test_loss += l.item()
                _,predicted = torch.max(outputs,axis = 1)
                predicted_list.append(predicted)
                labels_list.append(labels)
                test_total += labels.size(0)
                test_correct += torch.sum(predicted == labels).item()
                # print(labels,'\n',predicted)
    test_acc = test_correct/test_total
    print("Accuracy: {}".format(test_acc))
    # 打开一个.csv文件进行写入
    with open(output_path + '/test_acc_alone.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        row = [1, test_acc]
        writer.writerow(row)
    predicted_list=[aa.tolist() for aa in predicted_list]
    pred_list_total = [i for item in predicted_list for i in item]
    labels_list=[aa.tolist() for aa in labels_list]
    labels_list_total = [i for item in labels_list for i in item]
    all_features = np.concatenate(all_features, axis=0)
    
    return labels_list_total, pred_list_total, all_features

# %%
from utils import plot_confusion_matrix, plot_tsne
from models import fc_part
from sklearn.manifold import TSNE


new_model = resnet18(pretrained=True).to(device)
new_model.fc = fc_part().to(device)
new_model.load_state_dict(torch.load(output_path+"/adda_target_weights.pth"))

RANDOM_STATE_TSNE = 20

labels_list_total_test, pred_list_total_test, all_features_test = predict_gesture(new_model,target_test_loader,device)
plot_confusion_matrix(labels=labels_list_total_test,pre=pred_list_total_test,classes=['Pushing & Pulling','Beckoning','Rubbing Fingers'],savepath=output_path+'/Test_ConfMatrix',normalize=True)
tsne = TSNE(n_components=2, init='pca', random_state=RANDOM_STATE_TSNE)
tsne_result_test = tsne.fit_transform(all_features_test)
plot_tsne(tsne_result_test, labels_list_total_test, classes=['Pushing & Pulling','Beckoning','Rubbing Fingers'], savepath=output_path+'/Test_TSNE')
# Out:
# /home/lasso/anaconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning:
#
# The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#
# /home/lasso/anaconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning:
#
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#
# Test: 100%|██████████| 8/8 [00:00<00:00, 67.41it/s]
# Accuracy: 0.9416666666666667
# Normalized confusion matrix
# [[0.95 0.   0.05]
#  [0.   0.95 0.05]
#  [0.   0.08 0.92]]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sim_path = './simulated_data/'
real_path = './real_data/'
sim_txt_path = './simulated_data/sim.txt'
real_txt_path= './real_data/real.txt'
sim_all = {}
real_all = {}
for is_sim in [True,False]:
    if is_sim:
        for category in ['pic1','pic2','pic3']:
            sim_all[category] = glob.glob(os.path.join(sim_path + category,'*.jpg'))
    else:
        for category in ['pic1','pic2','pic3']:
            real_all[category] = glob.glob(os.path.join(real_path + category,'*.jpg'))
mapkey = {
    'pic1' : '0',
    'pic2' : '1',
    'pic3' : '2',
}
def gen_txt(txt_path, img_paths):
    f = open(txt_path,'w')
    for key in img_paths.keys():
        label = mapkey[key]
        for path in img_paths[key]:
            line = path + ' ' + label +'\n'
            f.write(line)
gen_txt(sim_txt_path,sim_all)
gen_txt(real_txt_path,real_all)
sim_data = MyDataset(txt_path=sim_txt_path,transform = sourceTransform)
sim_loader = DataLoader(dataset = sim_data,batch_size = batch_size)
real_data = MyDataset(txt_path=real_txt_path,transform = sourceTransform)
real_loader = DataLoader(dataset = real_data,batch_size = batch_size)

labels_list_total_sim, pred_list_total_sim, all_features_sim = predict_gesture(new_model,sim_loader,device)
labels_list_total_real, pred_list_total_real, all_features_real = predict_gesture(new_model,real_loader,device)

from utils import plot_tsne_v2

tsne = TSNE(n_components=2, init='pca', random_state=RANDOM_STATE_TSNE)
tsne_result_sim = tsne.fit_transform(all_features_sim)
tsne_result_real = tsne.fit_transform(all_features_real)
plot_tsne_v2(tsne_result_sim,labels_list_total_sim,tsne_result_real,labels_list_total_real,classes=['Pushing & Pulling','Beckoning','Rubbing Fingers'],savepath=output_path+'/ALL_TSNE',legend=True)
# Out:
# Test: 100%|██████████| 19/19 [00:00<00:00, 51.14it/s]
# Accuracy: 1.0
# Test: 100%|██████████| 19/19 [00:00<00:00, 64.64it/s]
# Accuracy: 0.91
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
